# %%
#!pwd
#!ls
import matplotlib.pyplot as plt
import numpy as np 

import matplotlib
matplotlib.use('TkAgg')

import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
# %cd yolov4-custom-functions/
# Out:
# [Errno 2] No such file or directory: 'yolov4-custom-functions/'
# /media/subhodip/3D4CD9331BAB9794/AI/Research/ai_research/project/yolo_object_detection/yolov4-custom-functions

# %%
#converting the darknet model to tnsorflow model
# !python save_model.py --weights ./data/yolov4-obj_cup_last.weights --output ./checkpoints/yolov4-obj_cup_last-416 --input_size 416 --model yolov4
# Out:
# 2021-05-01 20:36:51.575213: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory
# 2021-05-01 20:36:51.575348: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2021-05-01 20:36:54.574540: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2021-05-01 20:36:54.574677: W tensorflow/stream_executor/cuda/cuda_driver.cc:312] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-05-01 20:36:54.574776: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (subhodip): /proc/driver/nvidia/version does not exist
# ...

# %%
# Run yolov4 model while counting total objects detected
# !python detect.py --weights ./checkpoints/yolov4-obj_cup_last-416 --size 416 --model yolov4 --images ./data/images/bcup8.png --count
#!python detect.py --weights ./checkpoints/yolov4-416 --size 416 --model yolov4 --images ./data/images/car2.jpg --count
# Out:
# image_path ./data/images/bcup8.png
# Number of defective_cups: 1
# Number of cups: 1

# %%
#counting objects in video
#!python detect_video.py --weights ./checkpoints/yolov4-416 --size 416 --model yolov4 --video ./data/video/pizza_radmaker1.mp4  --count --output ./detections/pizza_radmaker1.avi
#--output ./detections/pizza_radmaker1.avi
# !python detect_video.py --weights ./checkpoints/yolov4-obj_cup_last-416 --size 416 --model yolov4 --video ./data/video/dcup_monkey1.mp4  --count --output ./detections/dcup_monkey1.avi 
#
# Out:
# started object detection
# output ./detections/dcup_monkey1.avi
# counted_classes {}
# width of plt (480, 640, 3)
# width of image (720, 1280, 3)
# width of concat (480, 1493, 3)
# FPS: 0.67
# counted_classes {}
# width of plt (480, 640, 3)
# width of image (720, 1280, 3)
# width of concat (480, 1493, 3)
# FPS: 1.47
# counted_classes {}
# width of plt (480, 640, 3)
# width of image (720, 1280, 3)
# width of concat (480, 1493, 3)
# FPS: 1.58
# counted_classes {}
# width of plt (480, 640, 3)
# width of image (720, 1280, 3)
# width of concat (480, 1493, 3)
# FPS: 1.48
# counted_classes {}
# width of plt (480, 640, 3)
# width of image (720, 1280, 3)
# width of concat (480, 1493, 3)
# FPS: 1.68
# counted_classes {}
# width of plt (480, 640, 3)
# width of image (720, 1280, 3)
# width of concat (480, 1493, 3)
# FPS: 1.42
# counted_classes {'defective_cup': 1}
# Number of defective_cups: 1
# width of plt (480, 640, 3)
# width of image (720, 1280, 3)
# width of concat (480, 1493, 3)
# ...

# %%
## for bcup_casey_glamour
width of plt (480, 640, 3)
width of image (466, 1280, 3)
width of concat (466, 1901, 3)

## for dcup_monkey1
width of plt (480, 640, 3)
width of image (720, 1280, 3)
width of concat (480, 1493, 3)

# %%
# Run yolov4 model while counting each class & detailed output
# !python detect.py --weights ./checkpoints/yolov4-416 --size 416 --model yolov4 --images ./data/images/dog.jpg --info --count
# Out:
# Number of bicycles: 1
# Number of dogs: 1
# Number of trucks: 1
# Object found: bicycle, Confidence: 0.99, BBox Coords (xmin, ymin, xmax, ymax): 127.0, 130.0, 567.0, 425.0
# Object found: dog, Confidence: 0.99, BBox Coords (xmin, ymin, xmax, ymax): 132.0, 232.0, 312.0, 537.0
# Object found: truck, Confidence: 0.92, BBox Coords (xmin, ymin, xmax, ymax): 466.0, 74.0, 693.0, 172.0

# %% [markdown]
# # Custom Yolov4

# %%
# !python save_model.py --weights ./data/yolov4-custom_2000.weights --output ./checkpoints/yolov4-custom_2000-416 --input_size 416 --model yolov4
# Out:
# 2021-04-29 21:21:33.758719: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory
# 2021-04-29 21:21:33.758830: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2021-04-29 21:21:37.922765: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2021-04-29 21:21:37.925006: W tensorflow/stream_executor/cuda/cuda_driver.cc:312] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-04-29 21:21:37.925121: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (subhodip): /proc/driver/nvidia/version does not exist
# ...

# %%
# !pwd
# Out:
# /media/subhodip/3D4CD9331BAB9794/AI/Research/ai_research/project/yolo_object_detection/yolov4-custom-functions

# %%
# Run yolov4 model while counting total objects detected
# !python detect.py --weights ./checkpoints/yolov4-custom_tire_2000-416 --size 416 --model yolov4 --images ./data/images/tire_eu2.png --count
# Out:
# image_path ./data/images/tire_eu2.png
# Number of tires: 3

# %%
#counting objects in video
# !python detect_video.py --weights ./checkpoints/yolov4-custom_tire_2000-416 --size 416 --model yolov4 --video ./data/video/tire_europa_70s.mp4 --output ./detections/tire_europa_70s.avi --count --tabulation
# Out:
# Number of tires: 3
# FPS: 0.70
# Number of tires: 3
# FPS: 1.65
# Number of tires: 3
# FPS: 1.73
# Number of tires: 4
# FPS: 1.86
# Number of tires: 4
# FPS: 1.82
# Number of tires: 3
# FPS: 1.94
# Number of tires: 3
# FPS: 1.90
# Number of tires: 3
# FPS: 1.79
# Number of tires: 2
# FPS: 1.86
# Number of tires: 2
# FPS: 1.89
# Number of tires: 2
# FPS: 1.74
# Number of tires: 3
# FPS: 1.31
# Number of tires: 3
# FPS: 1.20
# Number of tires: 4
# FPS: 1.22
# Number of tires: 4
# FPS: 1.21
# Number of tires: 3
# FPS: 1.19
# Number of tires: 3
# FPS: 1.21
# Number of tires: 3
# FPS: 1.20
# Number of tires: 3
# FPS: 1.23
# Number of tires: 3
# FPS: 1.17
# Number of tires: 3
# FPS: 1.23
# Number of tires: 3
# FPS: 1.23
# Number of tires: 2
# FPS: 1.23
# Number of tires: 3
# FPS: 1.24
# Number of tires: 3
# FPS: 1.21
# Number of tires: 2
# FPS: 1.26
# Number of tires: 2
# FPS: 1.22
# Number of tires: 2
# FPS: 1.22
# Number of tires: 2
# FPS: 1.27
# Number of tires: 3
# FPS: 1.20
# ...

# %%
a=5
abc.er=23
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7f1eda6f4063> in <module>
#       1 a=5
# ----> 2 abc.er=23
#
# NameError: name 'abc' is not defined

# %%
def do_sum(a,b):
    sum1=a+b
    return sum1

# %%
do_sum(2,3)
# Out:
# 5

# %%
sum1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-24dd84727fca> in <module>
# ----> 1 sum1
#
# NameError: name 'sum1' is not defined

# %%
import matplotlib
matplotlib.use('TkAgg')

import numpy as np
import cv2
import matplotlib.pyplot as plt

#fig = plt.figure()

#cap = cv2.VideoCapture('./data/video/pizza_radmaker1.mp4')
image=cv2.imread('./data/images/car2.jpg')
#image=cv2.cvtColor(image, cv2.COLOR_BGR2RGB)


x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)

y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)


#plt.plot(x1, y1, 'ko-')        # so that we can update data later

fig,ax=plt.subplots()
ax.plot(x1, y1, 'ko-')

#for i in range(10):
# update data
#line1.set_ydata(np.cos(2 * np.pi * (x1+i*3.14/2) ) * np.exp(-x1) )

# redraw the canvas
fig.canvas.draw()
#plt.show()


# convert canvas to image
img = np.fromstring(fig.canvas.tostring_rgb(), dtype=np.uint8,
        sep='')
print('no subplot1',img.shape)
img  = img.reshape(fig.canvas.get_width_height()[::-1] + (3,))
print('no subplot2',img.shape)
# img is rgb, convert to opencv's default bgr
img = cv2.cvtColor(img,cv2.COLOR_RGB2BGR)

print('no subplot3',img.shape)


# display image with opencv or any operation you like
cv2.imshow("plot",img)

# display camera feed
#ret,frame = cap.read()
#cv2.imshow("cam",frame)

#im_h=cv2.vconcat([frame,img])
#im_v_resize = vconcat_resize_min([image, img])
#cv2.imshow('im',im_v_resize)

k = cv2.waitKey(33) & 0xFF
if k == 12:
    #break
    cv2.destroyAllWindows()
# Out:
# no subplot1 (373248,)
# no subplot2 (288, 432, 3)
# no subplot3 (288, 432, 3)
# /home/subhodip/Studies_software/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:38: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead

# %%
#fig
#type(fig.canvas.draw())
#plt.
plt.close('all')
cv2.destroyAllWindows()

# %%
def vconcat_resize_min(im_list, interpolation=cv2.INTER_CUBIC):
    i=0
    for ele in im_list:
        #print(i, ele)
        i=i+1
    w_min = min(im.shape[1] for im in im_list)
    im_list_resize = [cv2.resize(im, (w_min, int(im.shape[0] * w_min / im.shape[1])), interpolation=interpolation)
                      for im in im_list]
    return cv2.vconcat(im_list_resize)

# %%
cv2.destroyAllWindows()

# %%
#plt.plot(x1, y1, 'ko-') 
#plt.show()
fig = plt.figure()

# %%
plt.plot(x1,y1, 'ko-')

# %%
fig.show()

# %%
# Some example data to display
x = np.linspace(0, 2 * np.pi, 400)
y = 10+np.sin(x ** 2)

'''
fig, axs = plt.subplots(2)
fig.suptitle('Vertically stacked subplots')
axs[0].plot(x, y)
axs[1].plot(x, -y)
'''
fig, (ax1, ax2) = plt.subplots(2, sharex=True)
#fig.suptitle('Aligning x-axis using sharex')
ax1.set_title("1st")
ax2.set_title("2nd")
ax1.plot(x, y)
ax2.plot(x, -y)
ax1.set(ylabel='count')
ax2.set(xlabel='frame',ylabel='count')
#ax2.xlabel('frame')

#plt.show()
#fig


fig.canvas.draw()

img = np.fromstring(fig.canvas.tostring_rgb(), dtype=np.uint8,
        sep='')
print('subplot1',img.shape)
img  = img.reshape(fig.canvas.get_width_height()[::-1] + (3,))
print('subplot2',img.shape)

# img is rgb, convert to opencv's default bgr
img = cv2.cvtColor(img,cv2.COLOR_RGB2BGR)
print('subplot3',img.shape)

cv2.imshow("plot",img)

k = cv2.waitKey(33) & 0xFF
if k == 12:
    #break
    cv2.destroyAllWindows()
# Out:
# /home/subhodip/Studies_software/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:28: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
# subplot1 (373248,)
# subplot2 (288, 432, 3)
# subplot3 (288, 432, 3)

# %%
plt.close('all')
cv2.destroyAllWindows()

# %%
img = np.fromstring(fig.canvas.tostring_rgb(), dtype=np.uint8,
        sep='')
img  = img.reshape(fig.canvas.get_width_height()[::-1] + (3,))

# img is rgb, convert to opencv's default bgr
img = cv2.cvtColor(img,cv2.COLOR_RGB2BGR)
# Out:
# /home/subhodip/Studies_software/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead

# %%
cv2.imshow("plot",img)

# %%
cv2.destroyAllWindows()

# %%
img.shape
# Out:
# (288, 432, 3)

# %%
cv2.imshow('im',img)

k = cv2.waitKey(33) & 0xFF
if k == 27:
    #break
    cv2.destroyAllWindows()

# %%
plt.plot()
# Out:
# []

# %%
plt.close()
fig, (ax1, ax2) = plt.subplots(2, sharex=True)
fig.suptitle('Aligning x-axis using sharex')
ax1.plot(x, y)
ax2.plot(x + 1, -y)
fig
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/home/subhodip/Studies_software/anaconda/lib/python3.6/tkinter/__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "/home/subhodip/Studies_software/anaconda/lib/python3.6/tkinter/__init__.py", line 749, in callit
#     func(*args)
#   File "/home/subhodip/Studies_software/anaconda/lib/python3.6/site-packages/matplotlib/backends/_backend_tk.py", line 270, in idle_draw
#     self.draw()
#   File "/home/subhodip/Studies_software/anaconda/lib/python3.6/site-packages/matplotlib/backends/backend_tkagg.py", line 9, in draw
#     super(FigureCanvasTkAgg, self).draw()
#   File "/home/subhodip/Studies_software/anaconda/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py", line 393, in draw
#     self.figure.draw(self.renderer)
#   File "/home/subhodip/Studies_software/anaconda/lib/python3.6/site-packages/matplotlib/backend_bases.py", line 1556, in _draw
# ...

# %%
dic={'A':'geek','B':'for'}

# %%
def getlist(dict):
    return dict.keys()

# %%
print(list(dic.keys()))
# Out:
# ['A', 'B']

# %%
key0,key1=list(dic.keys())

# %%
key0
# Out:
# 'A'
